# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.lines import Line2D
sns.set_theme(style="whitegrid")
sns.set_context("talk")

colors_blue = ['#5dade2', '#1f78b4', '#08306b']   # changed '#a6cee3' to a darker blue
colors_green = ['#58d68d', '#33a02c', '#006400']  # changed '#b2df8a' to a darker green
colors_red = ['#f1948a', '#e31a1c', '#99000d']    # changed '#fb9a99' to a darker red
colors_violet = ['#c39bd3', '#6a3d9a', '#4b0082'] # changed '#cab2d6' to a darker violet

# %% [markdown]
# # Residual history

# %% [markdown]
# ## $H_2$

# %%
beta = [16, 25, 32, 36, 40]
beta_2 = [16, 20, 25, 32, 36, 40]

# FLOPs_10 = np.array([274706911194, 672060980022, 862867465880, 4380870706860])
l50_buff1_5  = np.array([672060980022, 927787337668, 968899750776, 1075888740982, 1395928536726])
l100_buff1_5 = np.array([862867465880, 1125803501460, 1909286762342, 1193080964184, 1193080964184])
l200_buff1_5 = np.array([4380870706860, 1714328837080, 2068221607504, 2068221607504, 6366680232862])

# still running the remaning ones
l50_buff1_8  = np.array([683143701256, 814968271598, 789059448828, 837442178982, 942608462072, 1103151591522])
l100_buff1_8 = np.array([983090203700, 1043710643384, 1107707678836, 1326769612652, 1392427740670, 1263057123036])
l200_buff1_8 = np.array([114005824555848, 2631183494734, 1920600058000, 2306430137102, 2372548979528, 2521936220696])

l10_buff1_3 = np.array([247802382510, 247802382510, 247802382510, 247802382510])
l50_buff1_3 = np.array([501484799132, 616323855078, 662419001232, 867459537072, 867459537072, 867459537072])
l100_buff1_3 = np.array([ 804601527436,  848535474200, 1058233887798, 1081529764636, 1081529764636, 1131941474806])
l200_buff1_3 = np.array([2035541984338, 1442900465368, 1541977103638, 2383400666484, 2685400213950, 2758762296794])

# buffer 1.1
all= [717144184718, 715474976300, 543043898032, 850275844702, 657357226472, 979111563402, 762035930392, 939519869248, 762035930392, 988616394266, 762035930392, 988616394266]
l_50_buff1_1  = np.array(all[::2])
l_100_buff1_1 = np.array(all[1::2])
l_200_buff1_1 = np.array([3908958307630, 2117968661912, 2896145933318, 5571735380012, 6544293423732, 8397491023816])


Exact_diago = 20*(11994)**3

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 6), sharey=True)

# --- Plot for l = 50 ---
# axes[0].plot(beta, l50_buff1_5 / 1e12, marker='o', color=colors_red[0])
# axes[0].plot(beta_2, l50_buff1_8 / 1e12, marker='o', color=colors_green[0])
# axes[0].plot(beta_2, l50_buff1_3 / 1e12, marker='o', color=colors_blue[0])
# axes[0].plot(beta_2, l_50_buff1_1 / 1e12, marker='o', color=colors_violet[0])
# axes[0].set_title("nev = 50")
# axes[0].set_yscale('log')
# axes[0].set_xlabel(r"$\beta$")
# axes[0].set_ylabel(r"FLOPs (in trillions $10^{12}$)")
# axes[0].set_xticks([16, 20, 25, 32, 36, 40])
# axes[0].axhline(y=Exact_diago / 1e12, color='gray', linestyle='--', label='Exact diagonal')
# axes[0].grid(True)

# --- Plot for l = 100 ---
axes[0].plot(beta, l100_buff1_5 / 1e12, marker='s', color=colors_red[1])
axes[0].plot(beta_2, l100_buff1_8 / 1e12, marker='s', color=colors_green[1])
axes[0].plot(beta_2, l100_buff1_3 / 1e12, marker='s', color=colors_blue[1])
axes[0].plot(beta_2, l_100_buff1_1 / 1e12, marker='s', color=colors_violet[1])
axes[0].set_title(r"nev$ = 100 \cdot N_\text{occ}$")
axes[0].set_yscale('log')
axes[0].set_xlabel(r"$\beta$")
axes[0].set_ylabel(r"FLOPs (in trillions $10^{12}$)")
axes[0].set_xticks([16, 20, 25, 32, 36, 40])
axes[0].axhline(y=Exact_diago / 1e12, color='gray', linestyle='--', label='Exact diagonal')
axes[0].grid(True)

# --- Plot for l = 200 ---
axes[1].plot(beta, l200_buff1_5 / 1e12, marker='^', color=colors_red[2])
axes[1].plot(beta_2, l200_buff1_8 / 1e12, marker='^', color=colors_green[2])
axes[1].plot(beta_2, l200_buff1_3 / 1e12, marker='^', color=colors_blue[2])
axes[1].plot(beta_2, l_200_buff1_1 / 1e12, marker='^', color=colors_violet[2])
axes[1].set_title(r"nev$ = 200 \cdot N_\text{occ}$")
axes[1].set_yscale('log')
axes[1].set_xlabel(r"$\beta$")
axes[1].set_xticks([16, 20, 25, 32, 36, 40])
axes[1].axhline(y=Exact_diago / 1e12, color='gray', linestyle='--', label='Exact diagonal')
axes[1].grid(True)

# --- Shared Legend ---
legend_elements = [
    Line2D([0], [0], color='purple', lw=2, label='Buffer = 1.1'),
    Line2D([0], [0], color='blue', lw=2, label='Buffer = 1.3'),
    Line2D([0], [0], color='red', lw=2, label='Buffer = 1.5'),
    Line2D([0], [0], color='green', lw=2, label='Buffer = 1.8'),
    Line2D([0], [0], color='black', marker='o', lw=0, label='l = 50'),
    Line2D([0], [0], color='black', marker='s', lw=0, label='l = 100'),
    Line2D([0], [0], color='black', marker='^', lw=0, label='l = 200'),
    Line2D([0], [0], color='gray', lw=2, linestyle='--', label='Exact diagonal')
]

# fig.legend(handles=legend_elements, loc='lower center', ncol = 8, bbox_to_anchor=(0.5, -0.1))
fig.suptitle("FLOPs vs Beta for Different nev (Hydrogen)")
plt.tight_layout()
sns.despine()
plt.savefig("H2_FLOPS_vs_beta.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Formaldehyde

# %%
beta = [16, 20, 25, 32, 36]
beta_2 = [16, 25, 32]

# buffer = 1.5
FLOPs_10 = np.array([4963608819881, 4882511772896,4148365720086, 4372274410042, 4878703645662])
FLOPs_50 = np.array([49090151263844, 25308072779159,25426240907522, 25786871933884, 59042819012995])
FLOPs_100 = np.array([158707868900160, 41279873495703, 38471656220710, 35723179595297, 37130864981551])
FLOPs_200 = np.array([97802455405408, 68828434376950, 80876669157091, 80876669157091, 130122128665482])

# buffer = 1.3
arr_10_13 = np.array([3084295728594, 3652608309786, 4868101665714, 8314411537664, 5443193527940])
arr_50_13 = np.array([19743016320196, 18861788215334, 47791498260848, 58173204624552, 33678173456044])
arr_100_13 = np.array([46983105819758, 38616030335879, 33829969812886, 31721152655546, 65285560920983])
arr_200_13 = np.array([155527777783865, 68736205053077, 63604759856644, 73254371293122, 184617655327063])

# buffer = 1.8
FLOPs_10_18 = np.array([4187398601078, 3573313295724, 4782288701628])
FLOPs_50_18 = np.array([1214941812246062, 22793330032227, 29263983508140])
FLOPs_100_18 = np.array([66983105819758, 44107871941385, 41321996983879])
FLOPs_200_18 = np.array([355527777783865, 91773972764663, 92351630291964])

# buffer = 1.1
FLOPS_50_11 = np.array([17615551426316, 35392155493582, 51406707576678, 31470835556851, 54686075310651])
FLOPS_100_11 = np.array([39310987639580, 30776961005983, 79481125955265, 60725157144556, 60117582783638])
FLOPS_200_11 = np.array([93267712188224, 54257221844604, 53645885414284, 165059139130695, 188218746184612])

exact_diago = 20*(27643)**3

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True, sharex=True)

# --- Plot for l = 50 ---
axes[0].plot(beta, FLOPs_50 / 1e12, marker='o', color=colors_blue[0])
axes[0].plot(beta, arr_10_13 / 1e12, marker='o', color=colors_green[0])
axes[0].plot(beta_2, FLOPs_50_18 / 1e12, marker='o', color=colors_red[0])
axes[0].plot(beta, FLOPS_50_11 / 1e12, marker='o', color=colors_violet[0])
axes[0].set_title("l = 50")
axes[0].set_yscale('log')
axes[0].set_xlabel(r"$\beta$")
axes[0].set_ylabel("FLOPs (log scale, trillions)")
axes[0].axhline(y=exact_diago / 1e12, color='gray', linestyle='--', label='Exact diagonal')
axes[0].set_xticks([16, 20, 25, 32, 36])
axes[0].grid(True)

# --- Plot for l = 100 ---
axes[1].plot(beta, FLOPs_100 / 1e12, marker='s', color=colors_blue[1])
axes[1].plot(beta, arr_100_13 / 1e12, marker='s', color=colors_green[1])
axes[1].plot(beta_2, FLOPs_100_18 / 1e12, marker='s', color=colors_red[1])
axes[1].plot(beta, FLOPS_100_11 / 1e12, marker='s', color=colors_violet[1])
axes[1].set_title("l = 100")
axes[1].set_yscale('log')
axes[1].set_xlabel(r"$\beta$")
axes[1].set_xticks([16, 20, 25, 32, 36])
axes[1].axhline(y=exact_diago / 1e12, color='gray', linestyle='--', label='Exact diagonal')
axes[1].grid(True)

# --- Plot for l = 200 ---
axes[2].plot(beta, FLOPs_200 / 1e12, marker='^', color=colors_blue[2])
axes[2].plot(beta, arr_200_13 / 1e12, marker='^', color=colors_green[2])
axes[2].plot(beta_2, FLOPs_200_18 / 1e12, marker='^', color=colors_red[2])
axes[2].plot(beta[:], FLOPS_200_11 / 1e12, marker='^', color=colors_violet[2])
axes[2].set_title("l = 200")
axes[2].set_yscale('log')
axes[2].set_xlabel(r"$\beta$")
axes[2].set_xticks([16, 20, 25, 32, 36])
axes[2].axhline(y=exact_diago / 1e12, color='gray', linestyle='--', label='Exact diagonal')
axes[2].grid(True)

# --- Shared Legend ---
legend_elements = [
    Line2D([0], [0], color='purple', lw=2, label='Buffer = 1.1'),
    Line2D([0], [0], color='green', lw=2, label='Buffer = 1.3'),
    Line2D([0], [0], color='blue', lw=2, label='Buffer = 1.5'),
    Line2D([0], [0], color='red', lw=2, label='Buffer = 1.8'),
    Line2D([0], [0], color='black', marker='o', lw=0, label='l = 50'),
    Line2D([0], [0], color='black', marker='s', lw=0, label='l = 100'),
    Line2D([0], [0], color='black', marker='^', lw=0, label='l = 200'),
    Line2D([0], [0], color='gray', lw=2, linestyle='--', label='Exact diagonal')
]

fig.legend(handles=legend_elements, loc='lower center', ncol=8, bbox_to_anchor=(0.5, -0.1))
fig.suptitle("FLOPs vs Beta for Different l Values (Formaldehyde)")
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Uracile

# %%
beta = [16, 20, 25, 32]
beta2 = np.array([16, 25, 32])
beta3 = np.array([20, 25, 32])

# buffer 1.5
l50  = np.array([600456325825892, 90349595956788, 100593030078592, 91344730449524])
l100 = np.array([600456325825892, 211795227787616, 187532896506336, 232499149838272])
l200 = np.array([600456325825892, 430716627923104, 463388011832224, 866917412412992])

# buffer 1.8 (missing beta = 20 and l = 200!!)
l50_18  = np.array([131512152363476, 92131319021312, 102833941752896])
l100_18 = np.array([550e12, 365655702213152, 251527462477504, 264549223503424])
l200_18 = np.array([832e12, 750e12, 597996792348416, 762903524090688])

# buffer 1.3
l50_13  = np.array([91535026574436, 83460814900724, 162809891476984, 92712012760364])
l100_13 = np.array([235322706257212, 180625449004832,166811163320352, 191250895441920 ])
l200_13 = np.array([560e12, 406722494648448, 429414080585500, 658216526271456])

# buffer 1.1
FLOPS_50_11 = np.array([154546089399384, 189796579942176, 143645543013780, 137412304781472])
FLOPS_100_11 = np.array([197879190875188, 253857489121764, 339399552021092, 498925462945700])
FLOPS_200_11 = np.array([445533789534796, 323460595322080, 367692121231332, 573819850233048])


N_virt = 32416
exact_diago = 20*(N_virt)**3

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 6), sharey=True, sharex=True)

# --- Plot for l = 50 ---
# axes[0].plot(beta[1:], l50[1:] / 1e12, marker='o', color=colors_red[0])
# axes[0].plot(beta[1:], l50_18 / 1e12, marker='o', color=colors_green[0])
# axes[0].plot(beta, l50_13 / 1e12, marker='o', color=colors_blue[0])
# axes[0].plot(beta, FLOPS_50_11 / 1e12, marker='o', color=colors_violet[0])
# axes[0].set_title("l = 50")
# axes[0].set_xlabel(r"$\beta$")
# axes[0].set_ylabel("FLOPs (trillions)")
# axes[0].set_xticks([16, 20, 25, 32])
# axes[0].axhline(y=exact_diago / 1e12, color='gray', linestyle='--', label='Exact diagonal')
# axes[0].grid(True)

# --- Plot for l = 100 ---
axes[0].plot(beta, l100 / 1e12, marker='s', color=colors_red[1])
axes[0].plot(beta, l100_18 / 1e12, marker='s', color=colors_green[1])
axes[0].plot(beta, l100_13 / 1e12, marker='s', color=colors_blue[1])
axes[0].plot(beta, FLOPS_100_11 / 1e12, marker='s', color=colors_violet[1])
axes[0].set_title(r"nev$ = 100 \cdot N_\text{occ}$")
axes[0].set_xlabel(r"$\beta$")
axes[0].set_ylabel("FLOPs (trillions)")
axes[0].set_xticks([16, 20, 25, 32])
axes[0].axhline(y=exact_diago / 1e12, color='gray', linestyle='--', label='Exact diagonal')
axes[0].grid(True)

# --- Plot for l = 200 ---
axes[1].plot(beta, l200 / 1e12, marker='^', color=colors_red[2])
axes[1].plot(beta, l200_18 / 1e12, marker='^', color=colors_green[2])
axes[1].plot(beta, l200_13 / 1e12, marker='^', color=colors_blue[2])
axes[1].plot(beta, FLOPS_200_11 / 1e12, marker='^', color=colors_violet[2])
axes[1].set_title(r"nev$ = 200 \cdot N_\text{occ}$")
axes[1].set_xlabel(r"$\beta$")
axes[1].set_xticks([16, 20, 25, 32])
axes[1].axhline(y=exact_diago / 1e12, color='gray', linestyle='--')
axes[1].grid(True)

# --- Shared Legend ---
legend_elements = [
    Line2D([0], [0], color='purple', lw=2, label='Buffer = 1.1'),
    Line2D([0], [0], color='blue', lw=2, label='Buffer = 1.3'),
    Line2D([0], [0], color='red', lw=2, label='Buffer = 1.5'),
    Line2D([0], [0], color='green', lw=2, label='Buffer = 1.8'),
    # Line2D([0], [0], color='black', marker='o', lw=0, label='l = 50'),
    Line2D([0], [0], color='black', marker='s', lw=0, label='l = 100'),
    Line2D([0], [0], color='black', marker='^', lw=0, label='l = 200'),
    Line2D([0], [0], color='gray', lw=2, linestyle='--', label='Exact diagonal')    
]

fig.legend(handles=legend_elements, loc='lower center', ncol=7, bbox_to_anchor=(0.5, -0.1))
# plt.legend()
fig.suptitle("FLOPs vs Beta for Different nev (Uracile)")
sns.despine()
plt.tight_layout()
plt.savefig("Uracile_FLOPS_vs_beta.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# # Cosine verification

# %% [markdown]
# ## $H_2$

# %%
beta = [12, 16, 20, 25, 32, 36]
beta_2 = [16, 20, 25]

# FLOPs_10 = np.array([ ])
FLOPs_50 = np.array([569920266928, 672060692166, 760980185540, 920247123190, 961086042554, 1067879711952])
FLOPs_100 = np.array([872239953048, 899024842148, 958271497444, 1143741475986, 1956385390372, 1193080964184])
FLOPs_200 = np.array([133276582121628, 6432003662086, 1658183102284, 1782383704624, 2709680853436, 2709680853436])

# still running the remaning ones
l10  = np.array([359556386664, 359556386664, 359556386664])
l50  = np.array([711523711534, 508291310928, 551018176698])
l100 = np.array([980713588580, 1065384299226, 1082902843374])
l200 = np.array([101948772013890, 2266297223110, 1955647737394])

# %%
plt.figure(figsize=(10, 6))
plt.plot(beta, FLOPs_50 / 1e12, marker='o', label='l=50', color=colors_blue[0])
plt.plot(beta, FLOPs_100 / 1e12, marker='o', label='l=100', color=colors_blue[1])
plt.plot(beta, FLOPs_200 / 1e12, marker='o', label='l=200', color=colors_blue[2])

plt.plot(beta_2, l50 / 1e12, marker='o', label='l=50', color=colors_red[0])
plt.plot(beta_2, l100 / 1e12, marker='o', label='l=100', color=colors_red[1])
plt.plot(beta_2, l200 / 1e12, marker='o', label='l=200', color=colors_red[2])

plt.yscale('log')
plt.xlabel('Beta')
plt.ylabel('FLOPs (log scale, in trillions)')       
plt.title('FLOPs vs Beta for Different l Values ($H_2$)')
xticks = [12, 16, 20, 25, 32, 36]
plt.xticks(xticks)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Formaldehyde

# %%
beta = [16, 20, 25, 32, 36, 40]

FLOPs_10 = np.array([4148365720086, 4372274410042, 4878703645662, 4878703645662])
FLOPs_50 = np.array([20064592804272, 21707258446711, 46032697777503, 49682476666673 ])
FLOPs_100 = np.array([44225936796369, 50224406839724, 51788719785990, 51788719785990])
FLOPs_200 = np.array([114574873417791, 112901999750963, 112901999750963, 180568730548159])

# %%
plt.figure(figsize=(10, 6))
plt.plot(beta[2:], FLOPs_10 / 1e12, marker='o', label='l=10')
plt.plot(beta[2:], FLOPs_50 / 1e12, marker='o', label='l=50')
plt.plot(beta[2:], FLOPs_100 / 1e12, marker='o', label='l=100')
plt.plot(beta[2:], FLOPs_200 / 1e12, marker='o', label='l=200')
plt.yscale('log')
plt.xlabel('Beta')
plt.ylabel('FLOPs (log scale, in trillions)')
plt.title('FLOPs vs Beta for Different l Values (Formaldehyde)')
xticks = [16, 20, 25, 32, 36, 40]
plt.xticks(xticks)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Uracile

# %%
beta = [16, 20, 25, 32, 36, 40]

FLOPs_10 = np.array([4963608819881, 4882511772896,4148365720086, 4372274410042, 4878703645662, 4878703645662])
FLOPs_50 = np.array([49090151263844, 25308072779159,25426240907522, 25786871933884, 59042819012995, 53855303893381])
FLOPs_100 = np.array([158707868900160, 41279873495703, 38471656220710, 35723179595297, 37130864981551, 37130864981551])
FLOPs_200 = np.array([97802455405408, 68828434376950, 80876669157091, 80876669157091, 130122128665482])

# %%
plt.figure(figsize=(10, 6))
plt.plot(beta, FLOPs_10 / 1e12, marker='o', label='l=10')
plt.plot(beta, FLOPs_50 / 1e12, marker='o', label='l=50')
plt.plot(beta, FLOPs_100 / 1e12, marker='o', label='l=100')
# plt.plot(beta, FLOPs_200 / 1e12, marker='o', label='l=200')
plt.yscale('log')
plt.xlabel('Beta')
plt.ylabel('FLOPs (log scale, in trillions)')
plt.title('FLOPs vs Beta for Different l Values (Uracile)')
xticks = [16, 20, 25, 32, 36, 40]
plt.xticks(xticks)      
plt.legend()
plt.grid(True)
plt.show()
